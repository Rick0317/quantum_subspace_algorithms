# %%
import numpy as np
from DATA_MEASUREMENTS import *

# %%
time_per_circuit = 350    # microseconds
shot_overhead    = 390625 # Nshots to chemical accuracy of 1.6 mH


# following results are in seconds

h2o_vo_maxtime = (time_per_circuit * shot_overhead * np.max(H2O_VO_COSTS[0:17])) / 1000000
h2o_pt_maxtime = (time_per_circuit * shot_overhead * np.max(H2O_PT_COSTS[0:17])) / 1000000
n2_vo_maxtime  = (time_per_circuit * shot_overhead * np.max(N2_VO_COSTS[0:15])) / 1000000
n2_pt_maxtime  = (time_per_circuit * shot_overhead * np.max(N2_PT_COSTS[0:15])) / 1000000

# %%
# results in minutes

print(h2o_vo_maxtime / 60)
print(h2o_pt_maxtime / 60)
print(n2_vo_maxtime / 60)
print(n2_pt_maxtime / 60)
# Out:
# 3.8727963867981217
# 2.108378559860932
# 7.570524139796381
# 12.454668260392797
